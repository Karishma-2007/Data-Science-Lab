# %% [markdown]
# <a href="https://colab.research.google.com/github/Karishma-2007/Data-Science-Lab/blob/main/week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1
#
# ## Introduction to Data Science Tools
#
# ### Tools:
# - Google Colab
# - Python
# - Jupyter Notebook
# - Anaconda
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
